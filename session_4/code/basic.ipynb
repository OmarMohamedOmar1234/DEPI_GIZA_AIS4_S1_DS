# %%
import random
n = random.random()
n
# Out:
# 0.3446946173208977

# %%
lst = ["omar" , "ahmed" , "mohamed" , "ali "]
random.choice(lst)
# Out:
# 'omar'

# %%
import os
import sys

# %%
base="F:/HNU/DEPI_GIZA_AIS4_S1_DS/.env_DS/src/python/session_4/code"
type(base)
# Out:
# str

# %%
file = os.listdir(base)

# %%
print(file)
# Out:
# ['basic.ipynb']

# %%
os.remove(base+'/rem.txt')

# %%
base_dir = "./tmp_directory_test_again"
file_name = "text_1.txt"
file_path = os.path.join(base_dir , file_name)
os.remove (file_path)

# %%
directory = "./tmp_directory_test_again"
if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("directory already exists : ", directory)
# Out:
# directory already exists :  ./tmp_directory_test_again

# %%
path = "tmp_directory"
if not os.path.exists(path) :
    os.makedirs(path)
for i in range (20):
    inner_path = os.path.join(path , "dir_"+ str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)


def create_folders(path) :
    
    if not os.path.exists(path) :
     os.makedirs(path)
    for i in range (20):
      inner_path = os.path.join(path , "dir_"+ str(i))
      if not os.path.exists(inner_path):
         os.makedirs(inner_path)

# %%
from create_folder import create_folders
create_folders(path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 from create_folder import create_folders
#       2 create_folders(path)
#
# ModuleNotFoundError: No module named 'create_folder'

# %%
with open("./tmp_directory/text_1.txt","a+") as file :
    file.write("New line added \n")
    file.seek(0)
    updated_content = file.read()
    print(updated_content)
# Out:
# New line added

# %%
try:
    5/0
except:
    print("Not accept to divid by zero")
# Out:
# Not accept to divid by zero

# %%
try :
    x=10
    y=int(input())
    x/y
except:
    print('division by zero')
# Out:
# division by zero

# %%
try:
    5/0
except Exception as e :
    print(e)
# Out:
# division by zero

# %%
"""
this class 
"""

class StudentInfo :
    def __init__(self , student_name , age , gpa , gender):
                
        self.student_name =student_name
        self.age = 4
        self.Gpa = 3.99
        self.gender = "male"
    
        pass

    def student_info (self) :
        
        return f"welcome to {self.student_name}"

# %%
s1 = StudentInfo("omar" , 21 , 3.9 , "male")
s1.student_info()
# Out:
# 'welcome to omar'

# %%
class test :
    def info(self):
        print(self)

# %%
t1 = test()
print(t1)
print(t1.info())
# Out:
# <__main__.test object at 0x00000221121D3C50>
# <__main__.test object at 0x00000221121D3C50>
# None

# %%
class Calc :
    
    def __init__(self , num1: int , num2: int):
        self.num1 = num1
        self.num2 = num2
    
    def sum(self) :
        return self.num1 + self.num2
    
    def sub(self) :
        return self.num1 - self.num2

# %%
c1 = Calc(5 , 3)
c1.sum()
# Out:
# 8

# %%
from abc import ABC , abstractmethod
class Animal (ABC) :
    
    @abstractmethod
    def move (self):
        pass
    
    
class Bird (Animal):
    
    def move(self):
        print("bird")
        
        
class Cat (Animal):
    
    def move(self):
        print("Cat")

# %%
a = Bird()
a.move()
# Out:
# bird
