# %%
#TASK 1

email =input("enter your email ")
if "@" and "." in email :
    print("vaild email")
else :
    print("invaild email")
username = email.split("@")[0]
after_ex = email.split("@")[1]
domain = after_ex.split(".")[0]
print(username)
print(after_ex)
print(domain)
if email.endswith(".com") :
    print("Commercial Domain")
elif email.endswith(".edu") :
    print("Educational Domain")
else :
    print("Other Domain")
# Out:
# vaild email
# Amit_ml
# gmail.edu
# gmail
# Educational Domain

# %%
#TASK 2

encoded = "###!!@mocleW EPGTQ!!!6789"

core = encoded[6:18]
words = core.split()
decoded_first = words[0][::-1]
decoded_second = words[1]
print(core)
print(words)
print(decoded_first, decoded_second)
# Out:
# mocleW EPGTQ
# ['mocleW', 'EPGTQ']
# Welcom EPGTQ

# %%
#TASK 3
encoded = "&&&**$gnirtS PLIO!!@1234"
core = encoded[6:17]
words = core.split()
first = words[0][::-1]
second = words[1].replace("I", "E").replace("O", "U")
print(core)
print(words)
print(first, second)
# Out:
# gnirtS PLIO
# ['gnirtS', 'PLIO']
# String PLEU

# %%
#TASK 4
encoded = "##$$$@!yalpstcejorp EPUVT****9887"
core = encoded[7:25]
words = core.split()
first = words[0][::-1]
second = words[1].replace("E", "A").replace("U", "O")
print(core)
print(words)
print(first, second)
# Out:
# yalpstcejorp EPUVT
# ['yalpstcejorp', 'EPUVT']
# projectsplay APOVT
